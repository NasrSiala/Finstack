# %%
# Cell 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# Set style
sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (14, 6)

print("✓ Libraries imported successfully")

# %%
# Cell 2: Load processed data
data_path = "/app/data/processed/parquet/features"
# df = pd.read_parquet(data_path)

# Uncomment when data is available
# print(f"Loaded {len(df):,} records")
# print(f"\nColumns: {df.columns.tolist()}")
# print(f"\nData types:\n{df.dtypes}")
# print(f"\nDate range: {df['timestamp'].min()} to {df['timestamp'].max()}")
# print(f"\nAssets: {df['symbol'].unique().tolist()}")

# %%
# Cell 3: Visualize price trends
symbol = 'AAPL'
# df_symbol = df[df['symbol'] == symbol].sort_values('timestamp')

# fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Price chart
# axes[0].plot(df_symbol['timestamp'], df_symbol['close'], label='Close Price', linewidth=1.5)
# axes[0].plot(df_symbol['timestamp'], df_symbol['sma_20'], label='SMA(20)', alpha=0.7)
# axes[0].plot(df_symbol['timestamp'], df_symbol['sma_50'], label='SMA(50)', alpha=0.7)
# axes[0].fill_between(df_symbol['timestamp'], 
#                        df_symbol['bb_upper'], 
#                        df_symbol['bb_lower'], 
#                        alpha=0.2, label='Bollinger Bands')
# axes[0].set_title(f'{symbol} Price Analysis with Technical Indicators')
# axes[0].set_xlabel('Date')
# axes[0].set_ylabel('Price')
# axes[0].legend()
# axes[0].grid(True)

# Volume chart
# axes[1].bar(df_symbol['timestamp'], df_symbol['volume'], alpha=0.5)
# axes[1].set_title(f'{symbol} Trading Volume')
# axes[1].set_xlabel('Date')
# axes[1].set_ylabel('Volume')
# axes[1].grid(True)

# plt.tight_layout()
# plt.show()

# %%
# Cell 4: Returns analysis
# df_symbol['returns'].hist(bins=100, alpha=0.7, edgecolor='black')
# plt.axvline(df_symbol['returns'].mean(), color='red', linestyle='--', label='Mean')
# plt.title(f'{symbol} Returns Distribution')
# plt.xlabel('Returns')
# plt.ylabel('Frequency')
# plt.legend()
# plt.show()

# print(f"\nReturns Statistics:")
# print(f"  Mean: {df_symbol['returns'].mean():.6f}")
# print(f"  Std Dev: {df_symbol['returns'].std():.6f}")
# print(f"  Skewness: {df_symbol['returns'].skew():.4f}")
# print(f"  Kurtosis: {df_symbol['returns'].kurtosis():.4f}")

# %%
# Cell 5: Compare multiple assets
# symbols = df['symbol'].unique()[:5]

# plt.figure(figsize=(14, 8))
# for symbol in symbols:
#     df_symbol = df[df['symbol'] == symbol].sort_values('timestamp')
#     # Normalize prices to start at 100
#     normalized = (df_symbol['close'] / df_symbol['close'].iloc[0]) * 100
#     plt.plot(df_symbol['timestamp'], normalized, label=symbol, linewidth=1.5)

# plt.title('Normalized Price Comparison (Base = 100)')
# plt.xlabel('Date')
# plt.ylabel('Normalized Price')
# plt.legend()
# plt.grid(True)
# plt.show()
